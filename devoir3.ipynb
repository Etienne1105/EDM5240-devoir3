# %% [markdown]
# # Mon deuxième carnet : jouons avec les données sur les demandes
# # d'accès à l'information au niveau fédéral

# %%
import pandas as pan

# %%
info = pan.read_csv("ati.csv")
#Ici, j'ai demandé au carnet de lire mon fichier csv, que j'ai placé
#Dans le même fichier que mon nouveau carnet.

# %%
info
# Out:
#        year  month request_number  \
# 0      2016      3   A-2015-00070
# 1      2017      5   A-2016-00059
# 2      2016      3   A-2015-00059
# 3      2016      7   A-2016-00076
# 4      2016      3   A-2015-00113
# 5      2016      3   A-2015-00109
# 6      2016      3   A-2015-00108
# 7      2016      3   A-2015-00107
# 8      2016      3   A-2015-00082
# 9      2016      3   A-2015-00106
# 10     2016      3   A-2015-00100
# 11     2016      3   A-2015-00098
# 12     2016      3   A-2015-00085
# 13     2016      3   A-2015-00084
# 14     2016      3   A-2015-00063
# 15     2016      3   A-2015-00061
# 16     2016      3   A-2015-00058
# 17     2016      3   A-2015-00057
# 18     2016      3   A-2015-00052
# 19     2016      3   A-2014-00183
# 20     2016      3   A-2014-00182
# 21     2016      3   A-2014-00161
# 22     2016      3   A-2014-00160
# 23     2016      7   A-2016-00071
# 24     2017      7   A-2017-00063
# 25     2016     10   A-2016-00121
# ...

# %% [markdown]
# ## C'est à partir d'ici que nous commencerons à manipuler et nettoyer les informations pour essayer d'aller retirer des choses intéressantes

# %%
#La première chose que je fais faire, c'est de nettoyer le nom des colonnes
#de mon tableau pour le rendre plus facile à travailler.

info.columns
#J'utilise cette commande qui va m'afficher les éléments de la première
#ligne sous forme de liste. Je vais ensuite la copier et changer les
#éléments les un après les autres.
# Out:
# Index(['year', 'month', 'request_number', 'summary_en', 'summary_fr',
#        'disposition', 'pages', 'owner_org', 'owner_org_title'],
#       dtype='object')

# %%
info.columns = ['annee', 'mois', 'n_de_requete', 'resume_an', 'resume_fr',
       'disposition', 'pages', 'owner_org', 'proprietaire']

# %%
info
# Out:
#        annee  mois  n_de_requete  \
# 0       2016     3  A-2015-00070
# 1       2017     5  A-2016-00059
# 2       2016     3  A-2015-00059
# 3       2016     7  A-2016-00076
# 4       2016     3  A-2015-00113
# 5       2016     3  A-2015-00109
# 6       2016     3  A-2015-00108
# 7       2016     3  A-2015-00107
# 8       2016     3  A-2015-00082
# 9       2016     3  A-2015-00106
# 10      2016     3  A-2015-00100
# 11      2016     3  A-2015-00098
# 12      2016     3  A-2015-00085
# 13      2016     3  A-2015-00084
# 14      2016     3  A-2015-00063
# 15      2016     3  A-2015-00061
# 16      2016     3  A-2015-00058
# 17      2016     3  A-2015-00057
# 18      2016     3  A-2015-00052
# 19      2016     3  A-2014-00183
# 20      2016     3  A-2014-00182
# 21      2016     3  A-2014-00161
# 22      2016     3  A-2014-00160
# 23      2016     7  A-2016-00071
# 24      2017     7  A-2017-00063
# 25      2016    10  A-2016-00121
# 26      2016     4   A-2016-0002
# ...

# %% [markdown]
# ### Dans la prochaine section, je vais essayer d'isoler certaines colonnes pour tenter de trouver certaines informations.

# %%
info.n_de_requete.count()
#Ici, j'ai demandé au code de me donner le nombre de requête que compte
#Le graphique. J'aurais pu choisir n'importe quel case, mais j'ai ici su
#pposé que toutes les demandes avaient reçu un numéro d'identification

#J'ai voulu essayer de mettre du texte dans mon output. 
#(Ex: que ca affiche : (Nombres de demandes d'accès : XX) 
#Mais ça n'a pas fonctionné.
# Out:
# 28278

# %% [markdown]
# Dans la prochaine cellule, je vais essayer de voir quel est l'organisme qui a recu le plus de demandes

# %%
info.proprietaire.value_counts()
# Out:
# Global Affairs Canada | Affaires mondiales Canada                                                                                                                1799
# National Defence | Défense nationale                                                                                                                             1703
# Employment and Social Development Canada | Emploi et Développement social Canada                                                                                 1538
# Innovation, Science and Economic Development Canada | Innovation, Sciences et Développement économique Canada                                                    1395
# Immigration, Refugees and Citizenship Canada | Immigration, Réfugiés et Citoyenneté Canada                                                                       1394
# ...

# %% [markdown]
# ## On peut donc voir un apercu des organismes qui ont recu les plus de demande et le moins de demandes.
#
# ### Le plus : Affaires mondiales Canada (1799 demandes)
#
# ### Le moins : Fondation Asie Pacifique du Canada

# %%
#En regardant le tableau, je vois qu'une des colones est une sorte
#D'acronyme du nom de l'organisme ou du ministère propriétaire des
#informations. Pour ma propre culture, je vais faire une deuxième fois
#la requête précédente pour voir si le nombre de requête des indentique.

# %%
info.owner_org.value_counts()
# Out:
# dfatd-maecd     1799
# dnd-mdn         1703
# esdc-edsc       1538
# ic              1395
# cic             1394
# pco-bcp         1233
# nrcan-rncan     1187
# fin             1181
# lac-bac         1010
# hc-sc            975
# cra-arc          910
# cbsa-asfc        857
# tc               830
# jus              769
# ec               706
# pch              695
# aandc-aadnc      676
# ps-sp            675
# tbs-sct          649
# dfo-mpo          645
# rcmp-grc         579
# pwgsc-tpsgc      557
# cfia-acia        554
# pc               524
# vac-acc          457
# cnsc-ccsn        364
# aafc-aac         343
# ssc-spc          332
# infc             330
# csc-scc          318
#                 ...
# cnlopb            18
# vfpa-apvf         17
# ocl-cal           15
# bdc               15
# wdba-apwd         14
# jccbi-pjcci       12
# mai               12
# cpc-cpp           10
# oci-bec           10
# nserc-crsng        9
# fcac-acfc          9
# cca-cac            9
# ...

# %%
#Le résultat est probant, quand on regarde les deux listes,
#Le acronymes correspondent.

# %%
info.loc["annee","mois","resume_fr","proprietaire"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1433                 if not ax.contains(key):
# -> 1434                     error()
#    1435             except TypeError as e:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in error()
#    1428                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1429                                (key, self.obj._get_axis_name(axis)))
#    1430
#
# KeyError: 'the label [annee] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-1c61bbf959b1> in <module>()
# ----> 1 info.loc["annee","mois","resume_fr","proprietaire"]
#
# ...

# %%
#Pour une raison que j'ignore, cette fonction ne semble pas fonctionner

# %% [markdown]
# ### Maintenant, je vais essyaer d'affichier seulement les données dont
# ### aucun docuement n'a été transmis.

# %%
zero = info.disposition == "No records exist / Aucun documents existant"

# %%
info[zero]
# Out:
#      annee  mois  n_de_requete  \
# 3     2016     7  A-2016-00076
# 23    2016     7  A-2016-00071
# 33    2016     7  A-2016-00072
# 43    2016     7  A-2016-00077
# 62    2016     7  A-2016-00082
# 63    2016     7  A-2016-00078
# 64    2016     7  A-2016-00075
# 65    2016     7  A-2016-00074
# 66    2016     7  A-2016-00073
# 67    2016     7  A-2016-00070
# 68    2016     7  A-2016-00068
# 69    2016     7  A-2016-00065
# 70    2016     7  A-2016-00063
# 72    2016     7  A-2016-00060
# 73    2016     7  A-2016-00052
# 74    2016     7  A-2016-00043
# 81    2016     7  A-2014-00196
# 86    2016     7  A-2014-00189
# 87    2016     7  A-2014-00176
# 88    2016     7  A-2014-00175
# 94    2016     8  A-2016-00094
# 96    2016     8  A-2016-00092
# 145   2017     1  A-2016-00158
#
#                                              resume_an  \
# 3    The amount of funding provided to National Far...
# 23   The amount of funding provided to National Far...
# ...

# %%
### Voila! J'aurais pu continuer longtemps mais voici la fin de ce devoir.
